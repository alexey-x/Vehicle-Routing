# %% [markdown]
# # Описание задачи
#
# Содержание
#
# 1. Предисловие
#
# 2. Формулировка задачи - постулаты
#
# 3. Математическое описание
#
# 4. Замечания

# %% [markdown]
# ## 1. Предисловие

# %% [markdown]
# ### С чего все начилось

# %% [markdown]
# На одном собеседовании меня попросили решить "простую задачу":
#
# - Дан набор транспортных стредств (ТС) разной вместимости.
#
# - Требуется доставить нефть из базы, заказчикам в разных городах.
#
# - В одном городе может быть несколько заказов.
#
# - Заказ характризуется требуемым объемом, ценой по которой заказчик готов купить нефть и временным окном доставки.
#
# - В начальный момент времени все ТС находятся на базе.
#
# - В последний момент времени все ТС также должны быть на базе.
#
# - Загрузка данного ТС возможна только на базе.
#
# - Временем на загрузку или разгрузку ТС пренебрегаем.
#
# - Заданы расстояния между городами, стоимость за 1 км пути (для каждого ТС своя), время движения между городами (не зависит от ТС).
#
# - Требуется максимизировать операционную прибыль = выручка от продажи нефти заказчикам минус затраты на доставку.

# %% [markdown]
# Я покопался в интернете. Нашел хорошую работу "Time Constrained Routing and Scheduling". Мне показалось, что данная задача похожа на "The Vehicle Routing Problem with Time Windows (VRPTW)", поэтому я пытался математически сформулировать, поставленную мне задачу, в терминах VRPTW.

# %% [markdown]
# Промучился 4 дня. Решить, математически сформулировать, не удалось. Послал наработанный CPLEX код. И недоумевал, что это за простая задача.

# %% [markdown]
# В ответ ребята написали, что я почти решил, прислали свой вариант и предложили мне, чтобы я подправил свое решение соотвествующим образом.

# %% [markdown]
# Их решение меня разочаровало. Оно заключалось в следующем:
#
# - Берется одно ТС.
#
# - Выполняет какие-то заказы, тем самым уменьшая спрос.
#
# - Далее иттеративно используются другие ТС. (Это часть еще подлежала реализации).
#
# Очевидно, что значение целевой функции будет зависеть от того в какой последовательности будут иттерироваться ТС. Таким образом, нужно будет составить все возможные последовательности ТС. Для каждой последовательности найти суммарное значение прибыли и взять максимальное. Однако не факт, что это значение будет оптимальным. Предполагаю, что оно будет хуже, чем если бы все доступные ТС выполняли заказы одновременно.

# %% [markdown]
# Во-первых "затачиваться" под такое решение мне решительно не хотелось. Во-вторых мои переменные (decision variables) довольно сильно отличались от переменных ребят. В-третьих у ребят в решении использовались "трюки" с индексами переменных доступные в CPLEX, но от этого задача стала не похожей на задачу смешанного целочисленного программирования.

# %% [markdown]
# Вобщем я продолжил решать задачу в своем напрвалении (VRPTW). Потратил еще 3 дня. Силы закончились. Уперся в стену.
# Поблагодарил ребят за предоставленный второй шанс и отказался от дальнейших собеседованний.

# %% [markdown]
# ### Дальнейшие шаги

# %% [markdown]
# Мне все таки было интересно решить задачу, так чтобы машины ездили по заказчикам, возвращались на базу и опять отправлялись выполнять оставшиеся заказы, пока есть время.

# %% [markdown]
# Помогла страница Википедии [https://en.wikipedia.org/wiki/Vehicle_routing_problem]. Стало понятно, что мне надо искать задачи класса "Vehicle Routing Problem with Multiple Trips" (VRPMT) - одно ТС может сделать несколько маршрутов.

# %% [markdown]
# Обзорная статья Diego Cattaruzza и др. "Vehicle Routing Problem with Multiple Trips" сыграла ключевую роль -- помогла определиться с бизнес формулировкой задачи и выбрать переменные для математической формулировки.

# %% [markdown]
# ## 2. Формулировка задачи - постулаты

# %% [markdown]
# ## 3. Математическое описание

# %% [markdown]
# ## 4. Замечания
